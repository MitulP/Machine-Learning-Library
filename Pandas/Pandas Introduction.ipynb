# %%
Data Analytics
1. Pandas File read write and customization
2. Numpy Scientific computation 
3. matplotlib Data Visualization and Analysis
4. Seaborn Data Visualization advance
5. Sklearn Machine learning Regression ,Classification Clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
import pandas as pd
import numpy as np
import datetime

# %%
# to check existing funtion into that particular library
dir(pd)

# %%
# 1-D
ser = pd.Series([11,12,31])

# %%
ser
# Out:
# 0    11
# 1    12
# 2    31
# dtype: int64

# %%
# two dimension
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]])

# %%
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df = df.reindex([0,1,2])

# %%
df.sum(axis = 1)
# Out:
# 0     6
# 1    15
# 2    24
# dtype: int64

# %%
dic = {'Name':['ABC','BCD'],'Age':[20,90]}

# %%
dic
# Out:
# {'Age': [20, 90], 'Name': ['ABC', 'BCD']}

# %%
temp = pd.DataFrame(dic)

# %%
temp
# Out:
#    Age Name
# 0   20  ABC
# 1   90  BCD

# %%
temp['Age']
# Out:
# 0    20
# 1    90
# Name: Age, dtype: int64

# %%
temp['Name']
# Out:
# 0    ABC
# 1    BCD
# Name: Name, dtype: object

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Mitul'

# %%
#date read from CSV file
file = pd.read_csv('simple_demo.csv',header ='infer')

# %%
file
# Out:
#   Name   Age   city
# 0    A  20.0    AHM
# 1    B  30.0  Surat
# 2  NaN  60.0   vapi
# 3    D   NaN     MH

# %%
## Top Five rows from Dataframe
file.head(2)
# Out:
#   Name  Age   city
# 0    A   20    AHM
# 1    B   30  Surat

# %%
## Last Five rows from Dataframe
file.tail(1)
# Out:
#   Name  Age city
# 3    D   36   MH

# %%
#display integer col details
file.describe()
# Out:
#         Age
# count   4.0
# mean   36.5
# std    17.0
# min    20.0
# 25%    27.5
# 50%    33.0
# 75%    42.0
# max    60.0

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
# Name    3 non-null object
# Age     3 non-null float64
# city    4 non-null object
# dtypes: float64(1), object(2)
# memory usage: 176.0+ bytes

# %%
file[['Age','Name']]
# Out:
#     Age Name
# 0  20.0    A
# 1  30.0    B
# 2  60.0  NaN
# 3   NaN    D

# %%
file[(file['Age'] < 30) & (file['city'] == 'AHM')]
# Out:
#   Name  Age city
# 0    A   20  AHM

# %%
for i in file:
    print(i)
# Out:
# Name
# Age
# city

# %%
file.columns
# Out:
# Index(['Name', 'Age', 'city'], dtype='object')

# %%
file[['Age','city']]
# Out:
#    Age   city
# 0   20    AHM
# 1   30  Surat
# 2   60   vapi
# 3   36     MH

# %%
file.isnull()
# Out:
#     Name    Age   city
# 0  False  False  False
# 1  False  False  False
# 2   True  False  False
# 3  False  False  False

# %%
file['Name'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# Name: Name, dtype: bool

# %%
#file =file.dropna()

# %%
file
# Out:
#   Name   Age   city
# 0    A  20.0    AHM
# 1    B  30.0  Surat
# 2  NaN  60.0   vapi
# 3    D   NaN     MH

# %%
file['Name'].fillna('C')
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# Name: Name, dtype: object

# %%
file['Age'].fillna(36.5)
# Out:
# 0    20.0
# 1    30.0
# 2    60.0
# 3    36.5
# Name: Age, dtype: float64

# %%
#to get count of not null rows
file.count()
# Out:
# Name    3
# Age     3
# city    4
# dtype: int64

# %%
## dataframe[Rows,columns]
## i.e df[1:4,6:8]

file.iloc[0:3,1:3] # For integer Location
# Out:
#    Age   city
# 0   20    AHM
# 1   30  Surat
# 2   60   vapi

# %%
# String value based slicing for data frame
file.loc[0:3,'Age']
# Out:
# 0    20
# 1    30
# 2    60
# 3    36
# Name: Age, dtype: int64

# %%
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# # Panel

# %%
dataflair_pan = pd.Panel(np.random.randn(4,5,4), items=['1' ,'2' ,'3', '4'],
                         
                                                        major_axis=pd.date_range('1/2/2010', periods=5),minor_axis=['J','K','L','M'])

# %%
dataflair_pan
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 4 (items) x 5 (major_axis) x 4 (minor_axis)
# Items axis: 1 to 4
# Major_axis axis: 2010-01-02 00:00:00 to 2010-01-06 00:00:00
# Minor_axis axis: J to M

# %%
dataflair_pan['4']
# Out:
#                    J         K         L         M
# 2010-01-02  0.457936 -0.255506 -0.730870  0.511827
# 2010-01-03  0.263618  0.354634  0.244740 -0.062664
# 2010-01-04  0.601918 -0.404052 -0.682183 -0.230021
# 2010-01-05 -0.896696  1.227401 -0.585182  2.187060
# 2010-01-06  1.073445 -1.120228  0.528165 -0.786122

# %%
df = pd.read_csv('C:/Users/Mitul/Downloads/P6-OfficeSupplies.csv')

# %%
df.head()
# Out:
#      OrderDate   Region      Rep     Item  Units  Unit Price
# 0   4-Jul-2014     East  Richard  Pen Set     62        4.99
# 1  12-Jul-2014     East     Nick   Binder     29        1.99
# 2  21-Jul-2014  Central   Morgan  Pen Set     55       12.49
# 3  29-Jul-2014     East    Susan   Binder     81       19.99
# 4   7-Aug-2014  Central  Matthew  Pen Set     42       23.95

# %%
df.tail()
# Out:
#       OrderDate   Region      Rep    Item  Units  Unit Price
# 38  22-May-2015     West   Thomas  Pencil     32        1.99
# 39  31-May-2015  Central     Bill  Binder     80        8.99
# 40   8-Jun-2015     East  Richard  Binder     60        8.99
# 41  17-Jun-2015  Central  Matthew    Desk      5      125.00
# 42  25-Jun-2015  Central   Morgan  Pencil     90        4.99

# %%
df['Sales'] = df['Units'] * df['Unit Price']

# %%
df.head()
# Out:
#      OrderDate   Region      Rep     Item  Units  Unit Price    Sales
# 0   4-Jul-2014     East  Richard  Pen Set     62        4.99   309.38
# 1  12-Jul-2014     East     Nick   Binder     29        1.99    57.71
# 2  21-Jul-2014  Central   Morgan  Pen Set     55       12.49   686.95
# 3  29-Jul-2014     East    Susan   Binder     81       19.99  1619.19
# 4   7-Aug-2014  Central  Matthew  Pen Set     42       23.95  1005.90

# %%
df.groupby('Region').sum()
# Out:
#          Units  Unit Price     Sales
# Region
# Central   1199      432.45  11139.07
# East       691      118.87   6002.09
# West       231      321.95   2486.72

# %%
df.groupby('Region')['Sales','Units'].sum().sort_values(by=['Sales','Units'], ascending=True)
# Out:
#             Sales  Units
# Region
# West      2486.72    231
# East      6002.09    691
# Central  11139.07   1199

# %%
df['Region'].unique()
df['Region'].nunique()
# Out:
# array(['East', 'Central', 'West'], dtype=object)

# %%
df['Item'].value_counts()
# Out:
# Binder     15
# Pencil     13
# Pen Set     7
# Pen         5
# Desk        3
# Name: Item, dtype: int64

# %%
df['Item'].count()
# Out:
# 43

# %%
df.columns
# Out:
# Index(['OrderDate', 'Region', 'Rep', 'Item', 'Units', 'Unit Price', 'Sales'], dtype='object')

# %%
df.rename(columns = {'Unit Price':'UnitPrice','Region':'Reg'})
# Out:
#       OrderDate   Region      Rep     Item  Units  UnitPrice    Sales
# 0    4-Jul-2014     East  Richard  Pen Set     62       4.99   309.38
# 1   12-Jul-2014     East     Nick   Binder     29       1.99    57.71
# 2   21-Jul-2014  Central   Morgan  Pen Set     55      12.49   686.95
# 3   29-Jul-2014     East    Susan   Binder     81      19.99  1619.19
# 4    7-Aug-2014  Central  Matthew  Pen Set     42      23.95  1005.90
# 5   15-Aug-2014     East  Richard   Pencil     35       4.99   174.65
# 6   24-Aug-2014     West    James     Desk      3     275.00   825.00
# 7    1-Sep-2014  Central    Smith     Desk      2     125.00   250.00
# 8   10-Sep-2014  Central     Bill   Pencil      7       1.29     9.03
# 9   18-Sep-2014     East  Richard  Pen Set     16      15.99   255.84
# 10  27-Sep-2014     West    James      Pen     76       1.99   151.24
# 11   5-Oct-2014  Central   Morgan   Binder     28       8.99   251.72
# ...

# %%
df.head()
# Out:
#      OrderDate   Region      Rep     Item  Units  Unit Price    Sales
# 0   4-Jul-2014     East  Richard  Pen Set     62        4.99   309.38
# 1  12-Jul-2014     East     Nick   Binder     29        1.99    57.71
# 2  21-Jul-2014  Central   Morgan  Pen Set     55       12.49   686.95
# 3  29-Jul-2014     East    Susan   Binder     81       19.99  1619.19
# 4   7-Aug-2014  Central  Matthew  Pen Set     42       23.95  1005.90

# %% [markdown]
# ## Merge, join, and concatenate

# %% [markdown]
# ###  Concatenating objects

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                'B': ['B0', 'B1', 'B2', 'B3'],
                 'C': ['C0', 'C1', 'C2', 'C3'],
                'D': ['D0', 'D1', 'D2', 'D3']},
                 index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                 'C': ['C4', 'C5', 'C6', 'C7'],
                  'D': ['D4', 'D5', 'D6', 'D7']},
                   index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                 'B': ['B8', 'B9', 'B10', 'B11'],
                'C': ['C8', 'C9', 'C10', 'C11'],
                  'D': ['D8', 'D9', 'D10', 'D11']},
                 index=[8, 9, 10, 11])

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
frames = [df1, df2, df3]

result = pd.concat(frames)
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
result = pd.concat(frames, keys=['x', 'y', 'z'])

# %%
result
# Out:
#         A    B    C    D
# x 0    A0   B0   C0   D0
#   1    A1   B1   C1   D1
#   2    A2   B2   C2   D2
#   3    A3   B3   C3   D3
# y 4    A4   B4   C4   D4
#   5    A5   B5   C5   D5
#   6    A6   B6   C6   D6
#   7    A7   B7   C7   D7
# z 8    A8   B8   C8   D8
#   9    A9   B9   C9   D9
#   10  A10  B10  C10  D10
#   11  A11  B11  C11  D11

# %%
result.loc['x']
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                  'D': ['D2', 'D3', 'D6', 'D7'],
                   'F': ['F2', 'F3', 'F6', 'F7']},
                 index=[2, 3, 6, 7])

# %%
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
result = pd.concat([df1, df4], axis=1)
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
result = pd.concat([df1, df4], axis=1, join='inner')
result
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %%
df4.reindex()
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
pd.concat([df1, df4.reindex(df1.index)], axis=1)
# Out:
#     A   B   C   D    B    D    F
# 0  A0  B0  C0  D0  NaN  NaN  NaN
# 1  A1  B1  C1  D1  NaN  NaN  NaN
# 2  A2  B2  C2  D2   B2   D2   F2
# 3  A3  B3  C3  D3   B3   D3   F3

# %%
result = pd.concat([df1, df4], axis=1).reindex(df1.index)
result
# Out:
#     A   B   C   D    B    D    F
# 0  A0  B0  C0  D0  NaN  NaN  NaN
# 1  A1  B1  C1  D1  NaN  NaN  NaN
# 2  A2  B2  C2  D2   B2   D2   F2
# 3  A3  B3  C3  D3   B3   D3   F3

# %% [markdown]
# ### Concatenating using append

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
result = df1.append(df2)    
result
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
result = df1.append(df4)
result
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 2  NaN  B2  NaN  D2   F2
# 3  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
result = df1.append([df2, df3])
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
result = pd.concat([df1, df4], ignore_index=True)
result
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 4  NaN  B2  NaN  D2   F2
# 5  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
result = df1.append(df4, ignore_index=True)
result
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 4  NaN  B2  NaN  D2   F2
# 5  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %% [markdown]
# ### Concatenating with mixed ndims

# %%
df1.shape
# Out:
# (4, 4)

# %%
s1 = pd.Series(['X0', 'X1', 'X2', 'X3'], name='X')

# %%
s1
# Out:
# 0    X0
# 1    X1
# 2    X2
# 3    X3
# Name: X, dtype: object

# %%
result = pd.concat([df1, s1], axis=1)

# %%
result
# Out:
#     A   B   C   D   X
# 0  A0  B0  C0  D0  X0
# 1  A1  B1  C1  D1  X1
# 2  A2  B2  C2  D2  X2
# 3  A3  B3  C3  D3  X3

# %%
s2 = pd.Series(['_0', '_1', '_2', '_3'])

# %%
result = pd.concat([df1, s2, s2, s2,s1], axis=1)

# %%
result
# Out:
#     A   B   C   D   0   1   2   X
# 0  A0  B0  C0  D0  _0  _0  _0  X0
# 1  A1  B1  C1  D1  _1  _1  _1  X1
# 2  A2  B2  C2  D2  _2  _2  _2  X2
# 3  A3  B3  C3  D3  _3  _3  _3  X3

# %%
result = pd.concat([df1, s1], axis=1, ignore_index=True)

# %%
result
# Out:
#     0   1   2   3   4
# 0  A0  B0  C0  D0  X0
# 1  A1  B1  C1  D1  X1
# 2  A2  B2  C2  D2  X2
# 3  A3  B3  C3  D3  X3

# %% [markdown]
# ## Database-style DataFrame or named Series joining/merging¶

# %%
pd.merge(left, right, how='inner', on=None, left_on=None, right_on=None,
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                    'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3']})
left
# Out:
#     A   B key
# 0  A0  B0  K0
# 1  A1  B1  K1
# 2  A2  B2  K2
# 3  A3  B3  K3

# %%
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3']})
right
# Out:
#     C   D key
# 0  C0  D0  K0
# 1  C1  D1  K1
# 2  C2  D2  K2
# 3  C3  D3  K3

# %%
result = pd.merge(left, right, on='key')
result
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K2  C2  D2
# 3  A3  B3  K3  C3  D3

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                   'key2': ['K0', 'K1', 'K0', 'K1'],
                    'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
left
# Out:
#     A   B key1 key2
# 0  A0  B0   K0   K0
# 1  A1  B1   K0   K1
# 2  A2  B2   K1   K0
# 3  A3  B3   K2   K1

# %%
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0'],
                       'C': ['C0', 'C1', 'C2', 'C3'],
                       'D': ['D0', 'D1', 'D2', 'D3']})
right
# Out:
#     C   D key1 key2
# 0  C0  D0   K0   K0
# 1  C1  D1   K1   K0
# 2  C2  D2   K1   K0
# 3  C3  D3   K2   K0

# %%
result = pd.merge(left, right,how="inner" on=['key1', 'key2'])
result
# Out:
#     A   B key1 key2   C   D
# 0  A0  B0   K0   K0  C0  D0
# 1  A2  B2   K1   K0  C1  D1
# 2  A2  B2   K1   K0  C2  D2

# %%
result = pd.merge(left, right, how='left', on=['key1', 'key2'])
result
# Out:
#     A   B key1 key2    C    D
# 0  A0  B0   K0   K0   C0   D0
# 1  A1  B1   K0   K1  NaN  NaN
# 2  A2  B2   K1   K0   C1   D1
# 3  A2  B2   K1   K0   C2   D2
# 4  A3  B3   K2   K1  NaN  NaN

# %%
result = pd.merge(left, right, how='outer', on=['key1', 'key2'])
result
# Out:
#      A    B key1 key2    C    D
# 0   A0   B0   K0   K0   C0   D0
# 1   A1   B1   K0   K1  NaN  NaN
# 2   A2   B2   K1   K0   C1   D1
# 3   A2   B2   K1   K0   C2   D2
# 4   A3   B3   K2   K1  NaN  NaN
# 5  NaN  NaN   K2   K0   C3   D3

# %%
result = pd.merge(left, right, how='inner', on=['key1', 'key2'])
result
# Out:
#     A   B key1 key2   C   D
# 0  A0  B0   K0   K0  C0  D0
# 1  A2  B2   K1   K0  C1  D1
# 2  A2  B2   K1   K0  C2  D2

# %%
 left = pd.DataFrame({'A' : [1,2], 'B' : [1, 2]})
left
# Out:
#    A  B
# 0  1  1
# 1  2  2

# %%
right = pd.DataFrame({'A' : [4,5,6], 'B': [2, 2, 2]})
right
# Out:
#    A  B
# 0  4  2
# 1  5  2
# 2  6  2

# %%
result = pd.merge(left, right, on='B', how='outer')
result
# Out:
#    A_x  B  A_y
# 0    1  1  NaN
# 1    2  2  4.0
# 2    2  2  5.0
# 3    2  2  6.0

# %%
result = pd.merge(left, right, on='B', how='outer', validate="one_to_one")
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-26-65be18c5d9e1> in <module>()
# ----> 1 result = pd.merge(left, right, on='B', how='outer', validate="one_to_one")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      55                          right_index=right_index, sort=sort, suffixes=suffixes,
#      56                          copy=copy, indicator=indicator,
# ---> 57                          validate=validate)
#      58     return op.get_result()
#      59
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     573         # are in fact unique.
# ...

# %%
pd.merge(left, right, on='B', how='outer', validate="one_to_many")
# Out:
#    A_x  B  A_y
# 0    1  1  NaN
# 1    2  2  4.0
# 2    2  2  5.0
# 3    2  2  6.0

# %%
df1 = pd.DataFrame({'col1': [0, 1], 'col_left': ['a', 'b']})

df2 = pd.DataFrame({'col1': [1, 2, 2], 'col_right': [2, 2, 2]})

# %%
df1
# Out:
#    col1 col_left
# 0     0        a
# 1     1        b

# %%
df2
# Out:
#    col1  col_right
# 0     1          2
# 1     2          2
# 2     2          2

# %%
pd.merge(df1, df2, on='col1', how='outer', indicator=True)
# Out:
#    col1 col_left  col_right      _merge
# 0     0        a        NaN   left_only
# 1     1        b        2.0        both
# 2     2      NaN        2.0  right_only
# 3     2      NaN        2.0  right_only

# %%
pd.merge(df1, df2, on='col1', how='left', indicator=True)
# Out:
#    col1 col_left  col_right     _merge
# 0     0        a        NaN  left_only
# 1     1        b        2.0       both

# %% [markdown]
# ## Pivot

# %%
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 6,
                  'B': ['A', 'B', 'C'] * 8,
                 'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 4,
                  'D': np.random.randn(24),
                 'E': np.random.randn(24),
                 'F': [datetime.datetime(2013, i, 1) for i in range(1, 13)]
                 + [datetime.datetime(2013, i, 15) for i in range(1, 13)]})

# %%
pd.pivot_table(df, index=['A', 'B'], columns=['C'])
# Out:
#                 D                   E
# C             bar       foo       bar       foo
# A     B
# one   A  0.997492 -0.406092 -0.042840  0.468449
#       B -0.296170 -1.084054  0.906749 -1.016239
#       C -0.185498 -0.241858  0.335091  0.249489
# three A  0.578993       NaN -0.229919       NaN
#       B       NaN -0.182984       NaN  0.391782
#       C -1.087104       NaN -0.068586       NaN
# two   A       NaN -0.996818       NaN -0.381469
#       B -1.110750       NaN  0.395843       NaN
#       C       NaN -0.310969       NaN -0.332589

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A  0.997492 -0.406092
#       B -0.296170 -1.084054
#       C -0.185498 -0.241858
# three A  0.578993       NaN
#       B       NaN -0.182984
#       C -1.087104       NaN
# two   A       NaN -0.996818
#       B -1.110750       NaN
#       C       NaN -0.310969

# %%
pd.pivot_table(df, values='D', index=['B'], columns=['A', 'C'], aggfunc=np.sum)
# Out:
# A       one               three               two
# C       bar       foo       bar       foo     bar       foo
# B
# A  1.994985 -0.812185  1.157986       NaN     NaN -1.993637
# B -0.592340 -2.168108       NaN -0.365969 -2.2215       NaN
# C -0.370996 -0.483716 -2.174209       NaN     NaN -0.621937

# %%
pd.pivot_table(df, values=['D', 'E'], index=['B'], columns=['A', 'C'],aggfunc=np.sum)
# Out:
#           D                                                         E  \
# A       one               three               two                 one
# C       bar       foo       bar       foo     bar       foo       bar
# B
# A  1.994985 -0.812185  1.157986       NaN     NaN -1.993637 -0.085680
# B -0.592340 -2.168108       NaN -0.365969 -2.2215       NaN  1.813499
# C -0.370996 -0.483716 -2.174209       NaN     NaN -0.621937  0.670181
#
#
# A               three                 two
# C       foo       bar       foo       bar       foo
# B
# A  0.936897 -0.459837       NaN       NaN -0.762937
# B -2.032478       NaN  0.783563  0.791685       NaN
# C  0.498978 -0.137171       NaN       NaN -0.665178

# %%
df = pd.DataFrame({'row': [1, 2, 3],
                 'One_X': [1.1, 1.1, 1.1],
                  'One_Y': [1.2, 1.2, 1.2],
                  'Two_X': [1.11, 1.11, 1.11],
                  'Two_Y': [1.22, 1.22, 1.22]})

# %%
df

# %%
df = df.set_index('row')
df

# %% [markdown]
# ## Timeseries

# %%
dates = pd.date_range('2000-01-01', periods=5,freq='h')
dates
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 01:00:00',
#                '2000-01-01 02:00:00', '2000-01-01 03:00:00',
#                '2000-01-01 04:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
dates.to_period(freq='h').to_timestamp()
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 01:00:00',
#                '2000-01-01 02:00:00', '2000-01-01 03:00:00',
#                '2000-01-01 04:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %% [markdown]
# ## Plotting

# %%
df = pd.DataFrame(
    {'stratifying_var': np.random.uniform(0, 100, 20),
       'price': np.random.normal(100, 5, 20)})

# %%
df
# Out:
# array([ 95.52728175,  98.25374606, 103.43355849, 100.3534631 ,
#         98.80957876, 111.00489441,  93.19607762,  99.51070061,
#         99.05967397,  96.59344221, 104.37873649,  97.67663664,
#        104.15068391, 104.66757551,  99.80943484, 103.90689994,
#        111.85374426,  91.71154342,  93.53160145,  92.71294357])

# %%
df['quartiles'] = pd.qcut(
     df['stratifying_var'],
    4,
    labels=['0-25%', '25-50%', '50-75%', '75-100%'])

# %%
df['quartiles']
# Out:
# 0      50-75%
# 1      50-75%
# 2      25-50%
# 3      50-75%
# 4     75-100%
# 5     75-100%
# 6      25-50%
# 7      50-75%
# 8     75-100%
# 9      25-50%
# 10      0-25%
# 11      0-25%
# 12    75-100%
# 13      0-25%
# 14      0-25%
# 15     25-50%
# 16     25-50%
# 17    75-100%
# 18      0-25%
# 19     50-75%
# Name: quartiles, dtype: category
# Categories (4, object): [0-25% < 25-50% < 50-75% < 75-100%]

# %%
df.boxplot(column='price', by='quartiles')
